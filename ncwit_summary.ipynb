# %%
import pandas as pd 
pd.options.display.max_columns =999

# %%
ncwitDF = pd.read_csv('NCWIT-Data Cleaned.csv', low_memory= False)
ncwitDF.describe()
# Out:
#            Record#  Institution  Enroll, Female: Avg. ACT Math Score (Enrl F)  \
# count  2913.000000  2913.000000                                    309.000000
# mean   3281.770683   242.309303                                     26.692823
# std    1135.381983   144.845153                                      3.751993
# min    1226.000000     4.000000                                     17.000000
# 25%    2368.000000   110.000000                                     24.000000
# 50%    3246.000000   238.000000                                     27.000000
# 75%    4225.000000   368.000000                                     29.500000
# max    5356.000000   500.000000                                     35.000000
#
#        Enroll, Female: Asian (Enrl F)  Enroll, Female: Average Age (Enrl F)  \
# count                      814.000000                            754.000000
# mean                         4.568796                             19.922167
# ...
